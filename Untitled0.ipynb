# %%
x=2
print(x)
# Out:
# 2

# %%
x=1
print(x)
x="hello"
print(x)
x=[1,2,3]
print(x)
# Out:
# 1
# hello
# [1, 2, 3]

# %%
y=x
print(y)
# Out:
# [1, 2, 3]

# %%
x.append(4)
print(y)
# Out:
# [1, 2, 3, 4]

# %%
x="something alse"
print(y)
# Out:
# [1, 2, 3, 4]

# %%
x=4
type(x)
# Out:
# int

# %%
x="hello"
type(x)
# Out:
# str

# %%
x=3.14444
type(x)
# Out:
# float

# %%
(5+2)*(12/4)
# Out:
# 21.0

# %%
print(11/3)
# Out:
# 3.6666666666666665

# %%
print(11//3)
# Out:
# 3

# %%
2**5
# Out:
# 32

# %%
bin(12)
# Out:
# '0b1100'

# %%
bin(4)
# Out:
# '0b100'

# %%
12|4
# Out:
# 12

# %%
bin(1)
# Out:
# '0b1'

# %%
a=bin(5)
print(a)
# Out:
# 0b101

# %%
b=bin(67)
print(b)
# Out:
# 0b1000011

# %%
print(a or b)
# Out:
# 0b101

# %%
print(a and b)
# Out:
# 0b1000011

# %%
print(0b101<<0b1000011)
# Out:
# 737869762948382064640

# %%
print(0b101>>0b1000011)
# Out:
# 0

# %%
print(~0b101)
# Out:
# -6

# %%
print(~0b1000011)
# Out:
# -68
